# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('C:\\Users\\Truong\\Desktop\\Project\\Credit card fraud detection\\dataset.csv')
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
data.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
print(data.Class.value_counts())
print(data.Class.value_counts(normalize=True))
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64
# Class
# 0    0.998273
# 1    0.001727
# Name: proportion, dtype: float64

# %%
chart = data.drop(columns=['Class'])
cols_name = chart.columns.tolist()
fig, axs = plt.subplots(5,6,figsize=(20,20))
n = 0
for row in range(5):
    for col in range(6):
        sns.boxplot(ax=axs[row,col],data=chart[cols_name[n]])
        axs[row,col].set_title(cols_name[n])
        n +=1
plt.show()

# %%
corr = data.corr()
mask = np.triu(np.ones_like(corr,dtype=bool))
plt.figure(figsize=(20,20))
sns.heatmap(corr,mask=mask,linewidths=0.5,annot=True,fmt='.2f',cmap='Blues')
plt.show()

# %%
drop_columns = []
for column in data.columns:
    corrcoef = np.corrcoef(data['Class'],data[column])
    if np.abs(corrcoef[0,1]) < 0.02:
        drop_columns.append(column)
print(drop_columns)
# Out:
# ['Time', 'V8', 'V13', 'V15', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount']

# %%
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler

X = data.drop(columns='Class')
y = data['Class']
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=123, stratify= y)
X_train_drop = X_train.drop(columns=drop_columns)
X_test_drop = X_test.drop(columns=drop_columns)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score
from sklearn.metrics import make_scorer

# %%
log = LogisticRegression()
Knn = KNeighborsClassifier(n_neighbors=5)

# %%
Knn.fit(X_train_scaled,y_train)
Knn_pred_scaled = Knn.predict(X_test_scaled)
Knn.fit(X_train_drop,y_train)
Knn_pred_drop = Knn.predict(X_test_drop.values)
log.fit(X_train_scaled,y_train)
log_pred_scaled = log.predict(X_test_scaled)
log.fit(X_train_drop,y_train)
log_pred_drop = log.predict(X_test_drop)
# Out:
# c:\Users\Truong\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %%
result_report = pd.DataFrame()
result_report['model'] = ['knn_scaled','knn_drop','log_scaled','log_drop']
m = [Knn_pred_scaled,Knn_pred_drop,log_pred_scaled,log_pred_drop]
a_score = []
p_score = []
r_score = []
cm = []
for x in m:
    a = accuracy_score(y_test,x)
    a_score.append(a)
    p = precision_score(y_test,x)
    p_score.append(p)
    r = recall_score(y_test,x)
    r_score.append(r)
    cmatrix = confusion_matrix(y_test,x)
    cm.append(cmatrix)
result_report['accuracy_score'] = a_score
result_report['precision_score'] = p_score
result_report['recall_score'] = r_score
result_report['confusion_matrix'] = cm
result_report.set_index('model',inplace=True)
print(result_report)
# Out:
#             accuracy_score  precision_score  recall_score  \
# model
# knn_scaled        0.999427         0.930435      0.722973
# knn_drop          0.999473         0.940171      0.743243
# log_scaled        0.999157         0.865385      0.608108
# log_drop          0.999134         0.870000      0.587838
#
#                    confusion_matrix
# model
# knn_scaled  [[85287, 8], [41, 107]]
# knn_drop    [[85288, 7], [38, 110]]
# log_scaled  [[85281, 14], [58, 90]]
# log_drop    [[85282, 13], [61, 87]]
